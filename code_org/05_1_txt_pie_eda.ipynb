# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

end = './labels/20240202_18/'

ls_coco = os.listdir(end)

coco_path = []
for _ in ls_coco:
    coco_path.append(end + _)

class_id = []
label = []

for _ in coco_path:
    with open(_, 'r', encoding='utf-8') as f:
        txt = f.readlines()
    
    for _ in txt:

        # _.split(' ')[0] 는 txt파일에서 라벨
        class_id.append(_.split(' ')[0])
        if _.split(' ')[0] == '0':
            label.append('person')

        elif _.split(' ')[0] == '1':
            label.append('bicycle')

        elif _.split(' ')[0] == '2':
            label.append('car')

        elif _.split(' ')[0] == '3':
            label.append('motorcycle')

        elif _.split(' ')[0] == '4':
            label.append('bus')

        elif _.split(' ')[0] == '5':
            label.append('truck')            

data = {
    'num' : class_id,
    'label' : label
}

df = pd.DataFrame(data)
value = list(df.label.value_counts().sort_index().values)
index = list(df.label.value_counts().sort_index().index)
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

plt.title(f'data_v1 : {len(ls_coco)}')

plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
plt.show()

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

end = './labels/20240203_09/'

ls_coco = os.listdir(end)

coco_path = []
for _ in ls_coco:
    coco_path.append(end + _)

class_id = []
label = []

for _ in coco_path:
    with open(_, 'r', encoding='utf-8') as f:
        txt = f.readlines()
    
    for _ in txt:

        # _.split(' ')[0] 는 txt파일에서 라벨
        class_id.append(_.split(' ')[0])
        if _.split(' ')[0] == '0':
            label.append('person')

        elif _.split(' ')[0] == '1':
            label.append('bicycle')

        elif _.split(' ')[0] == '2':
            label.append('car')

        elif _.split(' ')[0] == '3':
            label.append('motorcycle')

        elif _.split(' ')[0] == '4':
            label.append('bus')

        elif _.split(' ')[0] == '5':
            label.append('truck')            

data = {
    'num' : class_id,
    'label' : label
}

df = pd.DataFrame(data)
value = list(df.label.value_counts().sort_index().values)
index = list(df.label.value_counts().sort_index().index)
explode = [0.05, 0.05, 0.05, 0.05, 0.05]

plt.title(f'data_v2 : {len(ls_coco)}')
plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
# plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
plt.show()

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

end = './labels/20240203_17/'

ls_coco = os.listdir(end)

coco_path = []
for _ in ls_coco:
    coco_path.append(end + _)

class_id = []
label = []

for _ in coco_path:
    with open(_, 'r', encoding='utf-8') as f:
        txt = f.readlines()
    
    for _ in txt:

        # _.split(' ')[0] 는 txt파일에서 라벨
        class_id.append(_.split(' ')[0])
        if _.split(' ')[0] == '0':
            label.append('person')

        elif _.split(' ')[0] == '1':
            label.append('bicycle')

        elif _.split(' ')[0] == '2':
            label.append('car')

        elif _.split(' ')[0] == '3':
            label.append('motorcycle')

        elif _.split(' ')[0] == '4':
            label.append('bus')

        elif _.split(' ')[0] == '5':
            label.append('truck')            

data = {
    'num' : class_id,
    'label' : label
}

df = pd.DataFrame(data)
value = list(df.label.value_counts().sort_index().values)
index = list(df.label.value_counts().sort_index().index)
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

plt.title(f'data_v3 : {len(ls_coco)}')

plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
plt.show()

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

end = './labels/20240205_14/'

ls_coco = os.listdir(end)

coco_path = []
for _ in ls_coco:
    coco_path.append(end + _)

class_id = []
label = []

for _ in coco_path:
    with open(_, 'r', encoding='utf-8') as f:
        txt = f.readlines()
    
    for _ in txt:

        # _.split(' ')[0] 는 txt파일에서 라벨
        class_id.append(_.split(' ')[0])
        if _.split(' ')[0] == '0':
            label.append('person')

        elif _.split(' ')[0] == '1':
            label.append('bicycle')

        elif _.split(' ')[0] == '2':
            label.append('car')

        elif _.split(' ')[0] == '3':
            label.append('motorcycle')

        elif _.split(' ')[0] == '4':
            label.append('bus')

        elif _.split(' ')[0] == '5':
            label.append('truck')            

data = {
    'num' : class_id,
    'label' : label
}

df = pd.DataFrame(data)
value = list(df.label.value_counts().sort_index().values)
index = list(df.label.value_counts().sort_index().index)
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# plt.title(f'data_v4 : {len(ls_coco)}')
plt.title(f'data_v4 : 28909')
plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
plt.show()

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

end = './labels/20240208_10/'

ls_coco = os.listdir(end)

coco_path = []
for _ in ls_coco:
    coco_path.append(end + _)

class_id = []
label = []

for _ in coco_path:
    with open(_, 'r', encoding='utf-8') as f:
        txt = f.readlines()
    
    for _ in txt:

        # _.split(' ')[0] 는 txt파일에서 라벨
        class_id.append(_.split(' ')[0])
        if _.split(' ')[0] == '0':
            label.append('person')

        elif _.split(' ')[0] == '1':
            label.append('bicycle')

        elif _.split(' ')[0] == '2':
            label.append('car')

        elif _.split(' ')[0] == '3':
            label.append('motorcycle')

        elif _.split(' ')[0] == '4':
            label.append('bus')

        elif _.split(' ')[0] == '5':
            label.append('truck')            

data = {
    'num' : class_id,
    'label' : label
}

df = pd.DataFrame(data)
value = list(df.label.value_counts().sort_index().values)
index = list(df.label.value_counts().sort_index().index)
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# plt.title(f'data_v5 : {len(ls_coco)}')
plt.title(f'data_v5 : 76157')
plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
plt.show()

# %% [markdown]
# # 버전1

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd

# txt파일 있는 폴더 지정
def class_pie_eda(txt_dir):
    ls_coco = os.listdir(end)

    coco_path = []
    for _ in ls_coco:
        coco_path.append(end + _)

    class_id = []
    label = []

    for _ in coco_path:
        with open(_, 'r', encoding='utf-8') as f:
            txt = f.readlines()
        
        for _ in txt:

            # _.split(' ')[0] 는 txt파일에서 라벨
            class_id.append(_.split(' ')[0])
            if _.split(' ')[0] == '0':
                label.append('person')

            elif _.split(' ')[0] == '1':
                label.append('bicycle')

            elif _.split(' ')[0] == '2':
                label.append('car')

            elif _.split(' ')[0] == '3':
                label.append('motorcycle')

            elif _.split(' ')[0] == '4':
                label.append('bus')

            elif _.split(' ')[0] == '5':
                label.append('truck')            

    data = {
        'num' : class_id,
        'label' : label
    }

    df = pd.DataFrame(data)
    value = list(df.label.value_counts().sort_index().values)
    index = list(df.label.value_counts().sort_index().index)
    explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

    plt.title(f'data : {len(ls_coco)}')
    plt.pie(value, labels=index, explode=explode, autopct='%.1f%%', shadow=True)
    plt.show()

# %%
end = './labels/20240208_10/'

class_pie_eda(end)
